# %% [markdown]
# # Analisis Data

# %% [markdown]
# ---
#
# ## 🍓✨ **Filosofi Brand: Fruit Glow**
#
# **Fruit Glow** hadir sebagai simbol harmoni antara **alam tropis Indonesia** dan **ilmu perawatan kulit modern**. Terinspirasi dari kekayaan buah-buahan lokal yang kaya akan vitamin, antioksidan, dan nutrisi alami, Fruit Glow memformulasikan produk skincare yang tidak hanya mempercantik dari luar, tapi juga menutrisi dari dalam.
#
# Dalam dunia yang serba cepat dan penuh tekanan, Fruit Glow menjadi oase yang menghadirkan kepercayaan diri dan kenyamanan melalui ritual perawatan kulit yang sederhana, efektif, dan menyenangkan. Kami percaya bahwa kulit yang sehat dan bercahaya adalah hasil dari keseimbangan antara **alam, sains, dan self-care**.
#
# ### 🌿 **Nilai Utama Fruit Glow**
# 1. **Natural Active Ingredients** – Kami memilih bahan alami dari buah-buahan seperti berry, citrus, dan tropical extract yang terbukti secara ilmiah.
# 2. **Science-Backed Formulas** – Didukung oleh penelitian dermatologis dan pengembangan laboratorium yang ketat.
# 3. **Affordable Wellness** – Keindahan kulit tidak harus mahal; produk kami terjangkau tanpa mengorbankan kualitas.
# 4. **Simplicity & Honesty** – Tidak ada klaim berlebihan. Kami berbicara jujur dan memberikan hasil nyata.
# 5. **Empowerment & Education** – Kami percaya pada kekuatan pengetahuan. Setiap pembelian adalah kesempatan untuk belajar merawat diri lebih baik.
#
# ---
#
# ## 🎯 **Visi Fruit Glow**
# Menjadi brand skincare lokal nomor satu yang dikenal karena **kualitas alami, hasil nyata, dan hubungan emosional** dengan konsumennya di seluruh Indonesia.
#
# ---
#
# ## 🧭 **Misi Fruit Glow**
# - Menyediakan rangkaian produk yang ramah kulit dan ramah lingkungan.
# - Meningkatkan kepercayaan diri setiap individu melalui kulit yang sehat dan bercahaya.
# - Membangun komunitas pelanggan cerdas yang paham pentingnya self-care dan skincare yang aman.
#
# ---
#
# ### 🌸 Filosofi "Glow"
# Bagi kami, “Glow” bukan hanya soal kulit yang cerah. Glow adalah ekspresi dari:
# - **Kesehatan**
# - **Ketenangan**
# - **Kepercayaan diri**
# - **Kebahagiaan dari dalam**
#
# ---

# %% [markdown]
# ### **Logo**
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Kita akan belajar analisis data Fruit Glow Sales 2024, untuk data fruit_glow_sales2024.xlsx bisa diunduh di sini: https://github.com/faruq1997/Bisnis_Intelligence
# Dalam belajaranya kita akan coba analisis dengan excel saja, direkomendasikan microsoft office excel di atas tahun 2010 ya…

# %% [markdown]
# ## 🧺 Deskripsi Dataset Penjualan (Sheet: Sales_Data)
#
# | Kolom             | Deskripsi                                                                 |
# |-------------------|--------------------------------------------------------------------------|
# | Order_ID          | ID unik transaksi (ex: SKN001, SKNBNDL002)                               |
# | Order_Date        | Tanggal transaksi (selalu tanggal 28 setiap bulan, untuk rekapan)        |
# | Province          | Nama provinsi konsumen                                                   |
# | Sales_Rep         | Nama lokal sales yang menangani                                          |
# | Product           | Nama produk atau bundling                                                |
# | Channel           | Platform penjualan: Offline, Shopee, Tokopedia, IG, TikTok              |
# | Quantity          | Jumlah produk terjual                                                    |
# | Price_per_Unit    | Harga per unit atau bundling                                             |
# | Brand             | Merek produk, default: Fruit Glow                                        |
# | Total_Sales       | Total = Quantity x Price_per_Unit                                        |
#
# ---
#
# ## 📦 Deskripsi Dataset Bundling (Sheet: Bundling_Details)
#
# | Kolom             | Deskripsi                                                               |
# |-------------------|------------------------------------------------------------------------|
# | Bundling_Product  | Nama produk bundling (ex: Paket Cerah, Paket Anti Jerawat)             |
# | Includes          | Isi produk individual dari paket bundling                              |
# | Bundling_Discount | Diskon yang diterapkan pada harga total jika dibeli paket              |
#
# ---
#
# ## 📊 Analisis & Insight
#
# ### 1. Informasi Mentah:
# - Penjualan per bulan/provinsi/produk/platform/sales
# - Produk terlaris, channel favorit, jumlah bundling
#
# ### 2. Pengetahuan (Insight):
# - Shopee & TikTok dominan → Fokus digital marketing
# - Bundling = pendapatan tinggi → promosikan lebih sering
# - Beberapa provinsi <5 unit → perlu strategi khusus
#
# ### 3. Kebijakan:
# - Alokasikan iklan ke Shopee/TikTok
# - Perluas variasi bundling
# - Kirimkan sales ke provinsi penjualan rendah
# - Beri bonus pada sales terbaik
# - Prediksi tren penjualan untuk pengadaan stok
#
# ---

# %% [markdown]
# ## Mari kita mulai

# %%
from google.colab import files
import pandas as pd

# Upload File
uploaded = files.upload()

# Baca Excel
file_path = list(uploaded.keys())[0]
xls = pd.ExcelFile(file_path)
sales_df = pd.read_excel(xls, sheet_name='Sales_Data')
bundling_df = pd.read_excel(xls, sheet_name='Bundling_Details')

sales_df.head()
# Out:
#      <input type="file" id="files-ecd03f16-e21a-4256-a961-2182764842bb" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ecd03f16-e21a-4256-a961-2182764842bb">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# ## ✅ **1. Informasi yang Bisa Didapat dari Data**
# Ini adalah *fakta mentah* yang bisa langsung diperoleh dari dataset:
#
# ### a. Informasi Penjualan
# - Total penjualan bulanan per produk, per channel, dan per provinsi.
# - Penjualan tertinggi dan terendah per produk.
# - Jumlah unit terjual dan total pemasukan.
# - Rata-rata harga jual dan quantity per order.
# - Produk bundling vs non-bundling: berapa kali dibeli dan total pendapatan.
#
# ### b. Informasi Channel Distribusi
# - Distribusi penjualan per platform: Shopee, Tokopedia, TikTok, Instagram, Offline.
# - Platform mana yang paling sering digunakan konsumen.
# - Distribusi wilayah: provinsi mana yang dominan belanja via marketplace vs offline.
#
# ### c. Informasi Sales Performance
# - Kinerja masing-masing sales: jumlah penjualan, produk yang dijual, provinsi yang dilayani.
# - Wilayah mana yang dikuasai oleh masing-masing sales.
#
# ### d. Informasi Regional (Wilayah)
# - Provinsi dengan penjualan terbanyak.
# - Provinsi dengan quantity <5 → bisa dianggap wilayah yang kurang potensial atau perlu strategi khusus.

# %% [markdown]
# ## Sudi Kasus - Analisis Data

# %% [markdown]
# Silahkan unduh data untuk studi kasus ini [https://github.com/faruq1997/Bisnis_Intelligence](https://github.com/faruq1997/Bisnis_Intelligence),
#
# `nama file: Data_PMB_UPG_2020_2024_Final.xlsx`
#
#
# Berikut adalah **deskripsi lengkap setiap kolom** dalam file Excel *Data PMB Final 2020–2024* beserta **informasi pendukungnya**:
#
# ---
#
# ### 🧾 **Deskripsi Kolom Data PMB**
#
# | **Kolom** | **Deskripsi** | **Informasi Tambahan / Pendukung** |
# |-----------|---------------|--------------------------------------|
# | `Tahun` | Tahun akademik saat pendaftaran berlangsung. | Rentang: 2020–2024. Menunjukkan tren tahunan PMB. |
# | `Periode` | Periode pembukaan pendaftaran mahasiswa baru. | Terdapat dua periode per tahun: **Maret** dan **September**. |
# | `Gelombang` | Tahapan atau gelombang pendaftaran dalam satu periode. | Terdapat **8 gelombang**, dengan **interval 20 hari** antar gelombang. |
# | `Tanggal Daftar` | Tanggal calon mahasiswa melakukan pendaftaran. | Dihitung berdasarkan gelombang dan periode. |
# | `Fakultas` | Fakultas tempat program studi berada. | Dua pilihan: **Fakultas Ekonomi dan Bisnis** & **Fakultas Teknologi Informasi**. |
# | `Program Studi` | Jurusan S1 yang dipilih oleh calon mahasiswa. | - Ekonomi & Bisnis: *Bisnis Digital*, *Manajemen*. <br> - Teknologi Informasi: *Sistem Informasi*, *Informatika*, *Sains Data*. |
# | `Kelas` | Jenis kelas perkuliahan yang diikuti. | - **Reguler**: Senin–Jumat, Pagi–Siang. <br> - **Karyawan**: Senin–Jumat, Sore–Malam. |
# | `SSP (Rp)` | Sumbangan Sarana Pendidikan. | Besarnya tergantung **gelombang**: <br> - Gelombang 1: **Gratis** <br> - Gelombang 2: Rp1.000.000 <br> - Tiap naik gelombang, tambah Rp500.000. |
# | `Biaya Kuliah (Rp)` | Biaya kuliah per semester. | - **Reguler**: Rp4.000.000 <br> - **Karyawan**: Rp4.500.000 |
# | `Sumber Pendaftaran` | Sumber informasi yang membuat calon mahasiswa tertarik mendaftar. | Contoh: *Relasi Dosen/Staf, Mitra Sekolah, Iklan Sosmed (IG, TikTok, FB), Alumni*, dll. |
# | `No Formulir` | Nomor formulir pendaftaran unik untuk tiap calon mahasiswa. | 9 digit angka unik (misal: `000000123`). |
# | `Nama Calon Mahasiswa` | Nama lengkap calon mahasiswa. | Nama bergaya generasi Z, tanpa gelar. |
# | `Asal Sekolah` | Nama sekolah asal calon mahasiswa. | Dibuat mirip format umum seperti: "PT. Harmoni High School". |
# | `Tahun Lulus` | Tahun calon mahasiswa lulus dari sekolah menengah. | Umumnya antara 2018–2024. |
# | `Tanggal Lahir` | Tanggal lahir calon mahasiswa. | Usia saat mendaftar berkisar 17–22 tahun. |
# | `Jenis Kelamin` | Jenis kelamin calon mahasiswa. | Pilihan: **Laki-laki**, **Perempuan**. |
# | `Kejuruan Sekolah` | Jurusan atau peminatan saat di sekolah menengah. | Contoh: *IPA, IPS, Teknik Komputer, Akuntansi, Multimedia, Pemasaran*, dll. |
# | `Biaya PraKuliah (Rp)` | Biaya kegiatan pra-kuliah yang wajib dibayar sebelum mulai kuliah. | Biaya tetap: **Rp1.000.000**. |
# | `Biaya Formulir (Rp)` | Biaya pembelian formulir pendaftaran. | Biaya tetap: **Rp260.000**. |
#
# ---
#
# ### 📊 **Catatan Analitik**
# - Kolom `SSP (Rp)` dan `Biaya Kuliah (Rp)` dapat digunakan untuk analisis *revenue forecasting*.
# - `Sumber Pendaftaran` penting untuk evaluasi **efektivitas promosi**.
# - `Kelas` dan `Program Studi` bisa digunakan untuk segmentasi dan alokasi dosen.
# - `Kejuruan Sekolah` dapat dikaitkan dengan keberhasilan akademik (data mining).
#
# ---

# %% [markdown]
# # Decision Support System (DSS)

# %% [markdown]
# ---
#
# ## 🧠 **Decision Support System (DSS): Implementasi pada Kasus Fruit Glow**
#
# ### 📌 Tujuan DSS di Fruit Glow
# Membantu manajemen *Fruit Glow* dalam:
# - Menentukan **wilayah prioritas pemasaran**.
# - Mengetahui **channel distribusi** paling efektif.
# - Menganalisis **kinerja tim sales**.
# - Menentukan **strategi produk** berdasarkan bundling, harga, dan permintaan.
# - Memberikan **rekomendasi keputusan** berbasis data.
#
# ---
#
# ## 🔍 **1. Fase DSS Berdasarkan Studi Kasus Fruit Glow**
#
# ### 🧭 Fase Intelijen
# - **Masalah:** Penjualan di beberapa provinsi sangat rendah (Quantity <5).
# - **Peluang:** Platform Shopee dan Tokopedia menunjukkan volume tinggi.
# - **Kebutuhan:** Menyesuaikan strategi pemasaran & penempatan sales di wilayah tertentu.
#
# ### 🏗️ Fase Desain
# - Menganalisis data historis 12 bulan.
# - Membandingkan performa bundling vs non-bundling.
# - Menentukan kriteria keberhasilan wilayah (misalnya: penjualan >Rp5 juta/bulan).
#
# ### 🧩 Fase Pilihan
# - Rekomendasi memperkuat promosi bundling karena memiliki AOV lebih tinggi.
# - Fokus promosi Shopee dan TikTok di daerah dengan volume tinggi.
# - Kirim sales baru ke wilayah "lemah" atau gunakan strategi reseller lokal.
#
# ### 🚀 Fase Implementasi
# - Menyusun *campaign* bundling dengan diskon 20% untuk IG & TikTok.
# - Memberikan komisi lebih tinggi kepada sales yang menjangkau provinsi low-quantity.
# - Membuat *landing page* khusus bundling untuk platform paling efektif.
#
# ---
#
# ## 🔧 **2. Komponen DSS pada Fruit Glow**
#
# | Komponen           | Implementasi di Fruit Glow                                       |
# |--------------------|------------------------------------------------------------------|
# | **Data Management** | Data penjualan 12 bulan, detail channel, provinsi, sales, produk |
# | **Model Management** | Model analisis channel, performa sales, bundling effectiveness   |
# | **Communication**   | Dashboard interaktif, laporan visual bulanan                    |
# | **Knowledge Management** | Insight pasar dan strategi pemasaran bundling & wilayah         |
#
# ---
#
# ## 📈 **3. Jenis Keputusan dalam DSS Fruit Glow**
#
# | Jenis DSS        | Contoh Kasus di Fruit Glow                                                                 |
# |------------------|---------------------------------------------------------------------------------------------|
# | **Terstruktur**   | Menentukan stok bulanan berdasarkan rerata penjualan produk tertentu per provinsi         |
# | **Semi Terstruktur** | Menentukan channel terbaik untuk promo produk baru menggunakan analisis performa sebelumnya |
# | **Tidak Terstruktur** | Strategi ekspansi ke provinsi baru yang selama ini tidak memiliki penjualan                |
#
# ---
#
# ## 🧠 **Output Knowledge yang Dihasilkan DSS Fruit Glow**
#
# | Informasi (Data)                                   | Pengetahuan yang Didapat                         | Keputusan/Kebijakan                           |
# |---------------------------------------------------|--------------------------------------------------|-----------------------------------------------|
# | Shopee & TikTok dominan dalam penjualan           | Dua channel paling efektif untuk campaign baru   | Fokus promosi di dua platform tersebut         |
# | Bundling 2+ produk → omzet lebih tinggi           | Produk bundling mendorong AOV dan repeat order  | Perbanyak variasi bundling dan diskon         |
# | Provinsi X-Y-Z Quantity <5                        | Potensi pasar rendah atau belum terjangkau      | Edukasi pasar atau rekrut reseller lokal       |
# | Sales A paling dominan di Jawa Tengah             | Kinerja kuat, cocok jadi team leader            | Berikan insentif, mentoring untuk sales lain  |
#
# ---
# `note: Average Order Value atau Rata-Rata Nilai Pemesanan.`
#
# ## 🌟 Kesimpulan
# Dengan pendekatan DSS, manajemen *Fruit Glow* tidak hanya memahami apa yang terjadi di lapangan, tapi **mengambil keputusan cerdas dan tepat berdasarkan analisis data**. Sistem DSS membantu Fruit Glow:
# - Fokus pada channel yang efektif.
# - Optimalkan kinerja tim sales.
# - Maksimalkan potensi wilayah.
# - Inovasi produk melalui bundling & harga dinamis.
#
# ---
